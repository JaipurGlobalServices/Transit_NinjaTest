# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email account credentials
from_email = 'Riya.jangid@jgservices.in'
password = 'Jgs@1234'
smtp_server = 'smtp.office365.com'
smtp_port = 587

# Create message
msg = MIMEMultipart()
msg['From'] = from_email
msg['To'] = 'arun.sankhla@jgservices.in'
msg['Subject'] = 'Subject of the Email'

# Add body to email
body = 'This is the body of the email.'
msg.attach(MIMEText(body, 'plain'))

# Set up the server
server = smtplib.SMTP(smtp_server, smtp_port)
server.starttls()  # Use TLS

try:
    # Login to the server
    server.login(from_email, password)
    
    # Send email
    text = msg.as_string()
    server.sendmail(from_email, 'recipient@example.com', text)
    print("Email sent successfully!")
    
except Exception as e:
    print(f"Failed to send email: {e}")
    
finally:
    # Close the server connection
    server.quit()
# Out:
# Failed to send email: (535, b'5.7.139 Authentication unsuccessful, SmtpClientAuthentication is disabled for the Tenant. Visit https://aka.ms/smtp_auth_disabled for more information. [PNYP287CA0045.INDP287.PROD.OUTLOOK.COM 2024-11-18T05:06:40.374Z 08DD068F5785F472]')

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email account credentials
from_email = 'notification@jgservices.in'
password = 'Jgs!@#$%^123'
smtp_server = 'smtpout.secureserver.net'
smtp_port = 465  # SSL port

# Create message
msg = MIMEMultipart()
msg['From'] = from_email
msg['To'] = 'arun.sankhla@jgservices.in'
msg['Subject'] = 'Subject of the Email - Test'

# Add body to email
body = 'This is the body of the email.'
msg.attach(MIMEText(body, 'plain'))

try:
    # Set up the server
    server = smtplib.SMTP_SSL(smtp_server, smtp_port)
    
    # Login to the server
    server.login(from_email, password)
    
    # Send email
    text = msg.as_string()
    server.sendmail(from_email, 'arun.sankhla@jgservices.in', text)
    print("Email sent successfully!")
    
except smtplib.SMTPException as e:
    print(f"Failed to send email: {e}")
    
finally:
    # Close the server connection
    try:
        server.quit()
    except smtplib.SMTPServerDisconnected:
        pass
# Out:
# Failed to send email: Connection unexpectedly closed

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email account credentials
from_email = 'notification@jgservices.in'
password = 'Jgs!@#$%^123'
smtp_server = 'jgservices.in'
smtp_port = 465  # SSL port

# Create message
msg = MIMEMultipart()
msg['From'] = from_email
msg['To'] = 'developer2.jgservices@gmail.com'
msg['Subject'] = 'Subject of the Email - Test'

# Add body to email
body = 'This is the body of the email.'
msg.attach(MIMEText(body, 'plain'))

try:
    # Set up the server
    server = smtplib.SMTP_SSL(smtp_server, smtp_port)  # Use SMTP_SSL for port 465
    
    # Login to the server
    server.login(from_email, password)
    
    # Send email
    text = msg.as_string()
    server.sendmail(from_email, 'arun.sankhla@jgservices.in', text)
    print("Email sent successfully!")
    
except smtplib.SMTPException as e:
    print(f"Failed to send email: {e}")
    
finally:
    # Close the server connection
    try:
        server.quit()
    except smtplib.SMTPServerDisconnected:
        pass
# Out:
# Email sent successfully!

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email account credentials
from_email = 'notification@jgservices.in'
password = 'Jgs!@#$%^123'
smtp_server = 'jgservices.in'
smtp_port = 465  # SSL port

# Create message
msg = MIMEMultipart()
msg['From'] = from_email
msg['To'] = 'arun.sankhla@jgservices.in'
msg['Subject'] = 'Subject of the Email - Test'

# Add body to email
body = 'This is the body of the email.'
msg.attach(MIMEText(body, 'plain'))

# Log email details
print(f"Sending email from: {from_email}")
print(f"Sending email to: arun.sankhla@jgservices.in")
print(f"Sending email to: developer2.jgservices@gmail.com")
print(f"SMTP server: {smtp_server}")
print(f"SMTP port: {smtp_port}")

try:
    # Set up the server
    server = smtplib.SMTP_SSL(smtp_server, smtp_port)  # Use SMTP_SSL for port 465
    
    # Login to the server
    server.login(from_email, password)
    
    # Send email
    text = msg.as_string()
    server.sendmail(from_email, ['arun.sankhla@jgservices.in', 'developer2.jgservices@gmail.com'], text)
    print("Email sent successfully!")
    
except smtplib.SMTPException as e:
    print(f"Failed to send email: {e}")
    
finally:
    # Close the server connection
    try:
        server.quit()
    except smtplib.SMTPServerDisconnected:
        pass
# Out:
# Sending email from: notification@jgservices.in
# Sending email to: arun.sankhla@jgservices.in
# Sending email to: developer2.jgservices@gmail.com
# SMTP server: jgservices.in
# SMTP port: 465
# Email sent successfully!

# %%
import mysql.connector
import logging
import configparser
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Set up logging
logging.basicConfig(filename='send_notifications.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

def send_email(email, order_id, tracking_id, status, purchase_date, seller_name):
    config = configparser.ConfigParser()
    config.read('config.ini')  # Read the config file

    from_email = config['email']['from_email']
    from_password = config['email']['password']
    smtp_server = config['email']['smtp_server']
    smtp_port = config['email']['smtp_port']

    subject = f"Order Update for {order_id}"
    body = f"""
    Hi,

    Your order with ID {order_id} purchased on {purchase_date} is currently at the following status: {status}.

    Tracking ID: {tracking_id}

    Thank you,
    {seller_name}
    """

    msg = MIMEMultipart()
    msg['From'] = from_email
    msg['To'] = email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    try:
        server = smtplib.SMTP_SSL(smtp_server, smtp_port)
        server.login(from_email, from_password)
        server.sendmail(from_email, email, msg.as_string())
        server.quit()
        logging.debug(f"Email sent successfully to {email}")
    except Exception as e:
        logging.error(f"Failed to send email: {e}")

def fetch_and_send_notifications():
    config = configparser.ConfigParser()
    config.read('config.ini')  # Read the config file

    conn = None
    cursor = None
    try:
        # Connect to the database using values from config.ini
        conn = mysql.connector.connect(
            host=config['database']['host'],
            user=config['database']['user'],
            password=config['database']['password'],
            database=config['database']['name']
        )
        cursor = conn.cursor()
        logging.debug('Database connection established')

        # Fetch all necessary details
        cursor.execute("SELECT email, order_id, tracking_id, status, purchase_date, seller_name FROM shipment_tracking_info")
        rows = cursor.fetchall()
        logging.debug(f'Fetched {len(rows)} rows from the database')

        for row in rows:
            email = row[0]
            order_id = row[1]
            tracking_id = row[2]
            status = row[3]
            purchase_date = row[4]
            seller_name = row[5]

            # Send email notification
            send_email(email, order_id, tracking_id, status, purchase_date, seller_name)
            logging.debug(f"Sent email to: {email}")

    except mysql.connector.Error as err:
        logging.error(f'Database error: {err}')
    except Exception as e:
        logging.error(f'Error in fetch_and_send_notifications: {e}')
    finally:
        if cursor is not None:
            cursor.close()
        if conn is not None:
            conn.close()
        logging.debug('Database connection closed')

if __name__ == "__main__":
    fetch_and_send_notifications()

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import ssl

# Email account credentials
from_email = 'notification@jgservices.in'
password = 'Jgs!@#$%^123'
smtp_server = 'jgservices.in'
smtp_port = 587  # TLS port

# Create message
msg = MIMEMultipart()
msg['From'] = from_email
msg['To'] = 'developer2.jgservices@gmail.com'
msg['Subject'] = 'Subject of the Email - Test'

# Add body to email
body = 'This is the body of the email.'
msg.attach(MIMEText(body, 'plain'))

# Log email details
print(f"Sending email from: {from_email}")
print(f"Sending email to: developer2.jgservices@gmail.com")
print(f"SMTP server: {smtp_server}")
print(f"SMTP port: {smtp_port}")

try:
    # Set up the server (SMTP for port 587)
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls(context=ssl.create_default_context())  # Use STARTTLS
    
    # Login to the server
    server.login(from_email, password)
    
    # Send email
    text = msg.as_string()
    server.sendmail(from_email, ['arun.sankhla@jgservices.in', 'developer2.jgservices@gmail.com'], text)
    print("Email sent successfully!")
    
except smtplib.SMTPException as e:
    print(f"Failed to send email: {e}")
    
finally:
    # Close the server connection
    try:
        server.quit()
    except smtplib.SMTPServerDisconnected:
        pass
# Out:
# Sending email from: notification@jgservices.in
# Sending email to: arun.sankhla@jgservices.in
# SMTP server: jgservices.in
# SMTP port: 587
# Email sent successfully!

# %%
import mysql.connector
import logging
import smtplib
import ssl
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import time

# Set up logging
logging.basicConfig(filename='send_notifications.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Email configuration
FROM_EMAIL = 'notification@jgservices.in'
EMAIL_PASSWORD = 'Jgs!@#$^%123'  # Use your actual email password or app-specific password
SMTP_SERVER = 'jgservices.in'
SMTP_PORT = 465  # SSL port

# Database configuration
DB_HOST = 'localhost'
DB_USER = 'root'
DB_PASSWORD = ''
DB_NAME = 'transit_ninja_db'

def send_email(email, order_id, tracking_id, status, purchase_date, seller_name):
    subject = f"Order Update for {order_id}"
    body = f"""
    Hi,

    Your order with ID {order_id} purchased on {purchase_date} is currently at the following status: {status}.

    Tracking ID: {tracking_id}

    Thank you,
    {seller_name}
    """

    msg = MIMEMultipart()
    msg['From'] = FROM_EMAIL
    msg['To'] = email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    retry_attempts = 3
    for attempt in range(retry_attempts):
        try:
            context = ssl.create_default_context()
            with smtplib.SMTP(SMTP_SERVER, 587) as server:
                server.starttls(context=context)
                logging.debug(f"Attempting to log in with {FROM_EMAIL}")
                server.login(FROM_EMAIL, EMAIL_PASSWORD)
                logging.debug(f"Authenticated successfully with {FROM_EMAIL}")
                server.sendmail(FROM_EMAIL, email, msg.as_string())
            logging.debug(f"Email sent successfully to {email}")
            return True  # Return True if the email is sent successfully
        except smtplib.SMTPAuthenticationError as auth_error:
            logging.error(f"Attempt {attempt + 1} - Authentication failed for {email}: {auth_error}")
            if attempt == retry_attempts - 1:  # Last attempt failed
                logging.error(f"Failed to authenticate and send email after {retry_attempts} attempts to {email}")
            time.sleep(2)  # Wait before retrying
        except smtplib.SMTPConnectError as conn_error:
            logging.error(f"Attempt {attempt + 1} - Connection failed for {email}: {conn_error}")
            if attempt == retry_attempts - 1:
                logging.error(f"Failed to connect and send email after {retry_attempts} attempts to {email}")
            time.sleep(2)  # Wait before retrying
        except Exception as e:
            logging.error(f"Attempt {attempt + 1} - Failed to send email to {email}: {e}")
            if attempt == retry_attempts - 1:
                logging.error(f"Failed to send email after {retry_attempts} attempts to {email}")
            time.sleep(2)  # Wait before retrying
    return False  # Return False if email was not sent successfully after all attempts


def fetch_and_send_notifications():
    conn = None
    cursor = None
    try:
        # Connect to the database
        conn = mysql.connector.connect(
            host=DB_HOST,
            user=DB_USER,
            password=DB_PASSWORD,
            database=DB_NAME
        )
        cursor = conn.cursor()
        logging.debug('Database connection established')

        # Fetch all necessary details
        cursor.execute("SELECT email, order_id, tracking_id, status, purchase_date, seller_name FROM shipment_tracking_info")
        rows = cursor.fetchall()
        logging.debug(f'Fetched {len(rows)} rows from the database')

        for row in rows:
            email = row[0]
            order_id = row[1]
            tracking_id = row[2]
            status = row[3]
            purchase_date = row[4]
            seller_name = row[5]

            # Send email notification
            send_email(email, order_id, tracking_id, status, purchase_date, seller_name)
            logging.debug(f"Sent email to: {email}")

    except mysql.connector.Error as err:
        logging.error(f'Database error: {err}')
    except Exception as e:
        logging.error(f'Error in fetch_and_send_notifications: {e}')
    finally:
        if cursor is not None:
            cursor.close()
        if conn is not None:
            conn.close()
        logging.debug('Database connection closed')

if __name__ == "__main__":
    fetch_and_send_notifications()

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import ssl
import configparser
import mysql.connector
import logging
import socket

# Set up logging
logging.basicConfig(filename='send_notifications.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Set default timeout
socket.setdefaulttimeout(10)  # 10 seconds timeout

# Read configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Database connection
db_host = config['database']['host']
db_user = config['database']['user']
db_password = config['database']['password']
db_name = config['database']['name']

# Email configuration
from_email = config['email']['from_email']
email_password = config['email']['password']
smtp_server = config['email']['smtp_server']
smtp_port = int(config['email']['smtp_port'])

def create_message(subject, body, to_email):
    msg = MIMEMultipart()
    msg['From'] = from_email
    msg['To'] = to_email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    return msg

def send_email(msg, to_email):
    server = None
    try:
        logging.debug("Connecting to the SMTP server using SSL...")
        server = smtplib.SMTP_SSL(smtp_server, smtp_port, context=ssl.create_default_context())
        server.set_debuglevel(1)  # Debugging output for SMTP
        server.login(from_email, email_password)
        server.sendmail(from_email, to_email, msg.as_string())
        logging.info(f"Email sent to {to_email}")
    except smtplib.SMTPException as e:
        logging.error(f"Failed to send email to {to_email}: {e}")
    finally:
        if server is not None:
            server.quit()

try:
    # Connect to the database
    conn = mysql.connector.connect(
        host=db_host,
        user=db_user,
        password=db_password,
        database=db_name
    )

    cursor = conn.cursor(dictionary=True)
    cursor.execute("SELECT tracking_id, shipment_partner, status, seller_name, contact_number, email, purchase_date, order_id FROM shipment_tracking_info WHERE 1=1")
    rows = cursor.fetchall()

    for row in rows:
        to_email = row['email']
        subject = "Tracking Update"
        body = f"Dear {row['seller_name']},\n\nYour shipment with tracking ID {row['tracking_id']} is currently {row['status']}."
        msg = create_message(subject, body, to_email)
        send_email(msg, to_email)

    cursor.close()
    conn.close()

except mysql.connector.Error as err:
    logging.error(f"Error connecting to the database: {err}")
except Exception as e:
    logging.error(f"An unexpected error occurred: {e}")

# %%
pip install yagmail
# Out:
# ...
#   Using cached yagmail-0.15.293-py2.py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached premailer-3.10.0-py2.py3-none-any.whl.metadata (15 kB)
# ...
# Using cached yagmail-0.15.293-py2.py3-none-any.whl (17 kB)
# Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\Python312\\Scripts\\yagmail.exe' -> 'c:\\Python312\\Scripts\\yagmail.exe.deleteme'
#
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import configparser
import mysql.connector
import logging
import socket
import yagmail

# Set up logging
logging.basicConfig(filename='send_notifications.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Set default timeout
socket.setdefaulttimeout(30)  # 30 seconds timeout

# Read configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Database connection
db_host = config['database']['host']
db_user = config['database']['user']
db_password = config['database']['password']
db_name = config['database']['name']

# Email configuration
from_email = config['email']['from_email']
email_password = config['email']['password']

def send_email(subject, body, to_email):
    try:
        yag = yagmail.SMTP(from_email, email_password)
        yag.send(to=to_email, subject=subject, contents=body)
        logging.info(f"Email sent to {to_email}")
    except yagmail.error.YagAddressError as e:
        logging.error(f"Invalid email address {to_email}: {e}")
    except yagmail.error.YagConnectionClosed as e:
        logging.error(f"Failed to send email to {to_email}: {e}")

try:
    # Connect to the database
    conn = mysql.connector.connect(
        host=db_host,
        user=db_user,
        password=db_password,
        database=db_name
    )

    cursor = conn.cursor(dictionary=True)
    cursor.execute("SELECT tracking_id, shipment_partner, status, seller_name, contact_number, email, purchase_date, order_id FROM shipment_tracking_info WHERE 1=1")
    rows = cursor.fetchall()

    for row in rows:
        to_email = row['email']
        subject = "Tracking Update"
        body = f"Dear {row['seller_name']},\n\nYour shipment with tracking ID {row['tracking_id']} is currently {row['status']}."
        send_email(subject, body, to_email)

    cursor.close()
    conn.close()

except mysql.connector.Error as err:
    logging.error(f"Error connecting to the database: {err}")
except Exception as e:
    logging.error(f"An unexpected error occurred: {e}")

# %%
import yagmail
import configparser
import logging

# Set up logging
logging.basicConfig(filename='send_notifications.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Read configuration
config = configparser.ConfigParser()
config.read('config.ini')

from_email = config['email']['from_email']
email_password = config['email']['password']
smtp_server = config['email']['smtp_server']
smtp_port = config['email']['smtp_port']

# Initialize Yagmail client
yag = yagmail.SMTP(from_email, email_password)

def send_email(to_email, subject, contents):
    try:
        yag.send(to=to_email, subject=subject, contents=contents)
        logging.debug(f"Email sent successfully to {to_email}")
    except yagmail.error.YagAddressError as e:
        logging.error(f"Failed to send email: Invalid address {to_email}")
    except yagmail.error.YagConnectionClosed as e:
        logging.error(f"Failed to send email: Connection closed unexpectedly {e}")
    except yagmail.error.YagInvalidEmailAddress as e:
        logging.error(f"Failed to send email: Invalid email address {e}")
    except Exception as e:
        logging.error(f"Failed to send email: {e}")

def fetch_and_send_notifications():
    try:
        conn = mysql.connector.connect(
            host=config['database']['host'],
            user=config['database']['user'],
            password=config['database']['password'],
            database=config['database']['name']
        )
        cursor = conn.cursor()
        logging.debug('Database connection established')

        cursor.execute("SELECT email, order_id, tracking_id, status, purchase_date, seller_name FROM shipment_tracking_info")
        rows = cursor.fetchall()
        logging.debug(f'Fetched {len(rows)} rows from the database')

        for row in rows:
            email = row[0]
            order_id = row[1]
            tracking_id = row[2]
            status = row[3]
            purchase_date = row[4]
            seller_name = row[5]

            subject = f"Order Update for {order_id}"
            contents = f"""
            Hi,

            Your order with ID {order_id} purchased on {purchase_date} is currently at the following status: {status}.

            Tracking ID: {tracking_id}

            Thank you,
            {seller_name}
            """
            
            send_email(email, subject, contents)
            logging.debug(f"Email sent to: {email}")

    except mysql.connector.Error as err:
        logging.error(f'Database error: {err}')
    except Exception as e:
        logging.error(f'Error in fetch_and_send_notifications: {e}')
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()
        logging.debug('Database connection closed')

if __name__ == "__main__":
    fetch_and_send_notifications()
